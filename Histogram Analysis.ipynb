# %% [markdown]
# # Analisis Data

# %%
# Library Import
import pandas as pd
from pandas import DataFrame
import graphviz
from sklearn import preprocessing
import pickle

# Algorithm
from sklearn.naive_bayes import GaussianNB
from sklearn import tree
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix

from collections import defaultdict
import matplotlib.pyplot as plt

# %%
atributeNames = ["age","workclass","fnlwgt","education","education-num","marital-status","occupation","relationship","race","sex","capital-gain","capital-loss","hours-per-week","native-country","target"]
income = pd.read_csv('data/CensusIncome.data.csv', header=None, names = atributeNames, sep = ",\s", engine="python", na_values="?");

# %%
label = defaultdict(LabelEncoder)
income = income.fillna("NaN")
income = income.apply(lambda x: x if x.dtype != 'O' else label[x.name].fit_transform(x))

# %% [markdown]
# # Histogram Analysis

# %% [markdown]
# ### Age Histogram

# %%
income.groupby("target").age.plot(kind="kde")

plt.figure();
plt.show()

# %% [markdown]
# ### Workclass Histogram

# %%
income.groupby("target").workclass.plot(kind="kde")

plt.figure()
plt.show()

# %% [markdown]
# ### Final Weight Histogram

# %%
income.groupby("target").fnlwgt.plot(kind="kde")

plt.figure()
plt.show()

# %% [markdown]
# ### Education Histogram

# %%
income.groupby("target").education.plot(kind="kde")

plt.figure()
plt.show()

# %% [markdown]
# ### Education Num Histogram

# %%
income.groupby("target")["education-num"].plot(kind="kde")

plt.figure()
plt.show()

# %% [markdown]
# ### Marital Status Histogram

# %%
income.groupby("target")["marital-status"].plot(kind="kde")

plt.figure()
plt.show()

# %% [markdown]
# ### Occupation Histogram

# %%
income.groupby("target")["occupation"].plot(kind="kde")

plt.figure()
plt.show()

# %% [markdown]
# ### Relationship Histogram

# %%
income.groupby("target")["relationship"].plot(kind="kde")

plt.figure()
plt.show()

# %% [markdown]
# ### Race Histogram

# %%
income.groupby("target")["race"].plot(kind="kde")

plt.figure()
plt.show()

# %% [markdown]
# ### Sex Histogram

# %%
income.groupby("target")["sex"].plot(kind="kde")

plt.figure()
plt.show()

# %% [markdown]
# ### Capital Gain Histogram

# %%
income.groupby("target")["capital-gain"].plot(kind="kde")

plt.figure()
plt.show()

# %% [markdown]
# ### Capital Loss Histogram

# %%
income.groupby("target")["capital-loss"].plot(kind="kde")

plt.figure()
plt.show()

# %% [markdown]
# ### Hours per Week Histogram

# %%
income.groupby("target")["hours-per-week"].plot(kind="kde")

plt.figure()
plt.show()

# %% [markdown]
# ### Native Country Histogram

# %%
income.groupby("target")["native-country"].plot(kind="kde")

plt.figure()
plt.show()

# %% [markdown]
# ## Conclusion
#
# Column Race, Native Country will be dropped since those column doesn't look like 'difference maker'
